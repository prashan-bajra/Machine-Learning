# %%
# libraries and data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
df = pd.read_csv("data2.csv")

# Make a data frame
 
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,9))
 
# create a color palette
palette = plt.get_cmap('Set1')
df.head()
 
# multiple line plot
num=0
for column in df.drop('Time', axis=1):
    num+=1
 
    # Find the right spot on the plot
    plt.subplot(2,3, num)
 
    # plot every groups, but discreet
    for v in df.drop('Time', axis=1):
        
        plt.plot(df['Time'], df[v], marker='', color='black', linewidth=1.6, alpha=0.1)
 
    # Plot the lineplot
    plt.plot(df['Time'], df[column], marker='', color=palette(num), linewidth=2.4, alpha=0.9, label=column)
    
    # limits!
    #plt.xlim(0,100)
    #plt.ylim(0,260)
     
        
    #plt.xticks(np.arange(0,110,20), np.arange(0,110,20))
    plt.yticks(np.arange(0,260,40), np.arange(0,260,40))
    plt.xlabel("Time in seconds")
    plt.ylabel("Temperature")
    
    # Add title
    plt.title(column, loc='left', fontsize=16, fontweight=0, color=palette(num) )
 
# general title
plt.suptitle("Temperature profiles of different EPCs", fontsize=18, fontweight=0, color='black', style='normal', y=1.02)

# Axis title
plt.text(0.5, 0.02, 'Time', ha='center', va='center')
plt.text(0.06, 0.5, 'Note', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.06, 0.5, 'Note')

# %%
# libraries and data
#import matplotlib.pyplot as plt
#import numpy as np
#import pandas as pd
#from datetime import datetime, timedelta

#epc1 = pd.read_csv("data1.csv", parse_dates=['Time'], index_col='Time')
#epc1.plot()

# %%
# libraries and data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
df = pd.read_csv("data2.csv", parse_dates=True, squeeze=True)
time = df['Time']
Urban = df['Urban']
Kenwood= df['Kenwood']

plt.plot(time,Urban, label = 'Urban')
plt.plot(time,Kenwood, label = 'Kenwood')
plt.xlabel('time in seconds')
# Out:
# Text(0.5, 0, 'time in seconds')

# %%
# libraries and data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
df = pd.read_csv("dataV1.csv")

# Make a data frame
 
# Initialize the figure
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,9))
 
# create a color palette
palette = plt.get_cmap('Set1')
df.head()
 
# multiple line plot
num=0
for column in df.drop('Time', axis=1):
    num+=1
 
    # Find the right spot on the plot
    plt.subplot(2,3, num)
 
    # plot every groups, but discreet
    for v in df.drop('Time', axis=1):
        
        plt.plot(df['Time'], df[v], marker='', color='black', linewidth=1.6, alpha=0.1)
 
    # Plot the lineplot
    plt.plot(df['Time'], df[column], marker='', color=palette(num), linewidth=2.4, alpha=0.9, label=column)
    
    # limits!
    #plt.xlim(0,100)
    #plt.ylim(0,260)
     
        
    #plt.xticks(np.arange(0,110,20), np.arange(0,110,20))
    #plt.yticks(np.arange(0,260,40), np.arange(0,260,40))
    plt.xlabel("Time in seconds")
    plt.ylabel("Power(W)")
    
    # Add title
    plt.title(column, loc='left', fontsize=16, fontweight=0, color=palette(num) )
 
# general title
plt.suptitle("Temperature profiles of different EPCs", fontsize=18, fontweight=0, color='black', style='normal', y=1.02)

# Axis title
plt.text(0.5, 0.02, 'Time', ha='center', va='center')
plt.text(0.06, 0.5, 'Note', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.06, 0.5, 'Note')
